# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
import tensorflow as tf
import segmentation_models as sm
import glob
import cv2
import os
import numpy as np
import datetime
from matplotlib import pyplot as plt
import keras
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
#from keras.utils import normalize
from keras.utils.np_utils import normalize
from keras.metrics import MeanIoU

# %%
#Images size
SIZE_X = 128
SIZE_Y = 128

# %%
#Capture training images into a list
train_images = []

for directory_path in glob.glob("saroadscenes_data/Images_128"):
    for img_path in glob.glob(os.path.join(directory_path, "*.tiff")):
        img = cv2.imread(img_path, 0)
        train_images.append(img)
#Convert list to array
train_images = np.array(train_images)


#Capture mask/label info as a list
train_masks = []

for directory_path in glob.glob("saroadscenes_data/Masks_128"):
    for mask_path in glob.glob(os.path.join(directory_path, "*.tiff")):
        mask = cv2.imread(mask_path, 0)
        train_masks.append(mask)
#Convert list to array
train_masks = np.array(train_masks)

# %%
np.unique(train_masks)
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=uint8)

# %%
#Encode labels - 0,1,2,3 instead of 1,2,3,4
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape
train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
np.unique(train_masks_encoded_original_shape)
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
#Expand dims to fit U-Net
train_images = np.expand_dims(train_images, axis=3)
train_images = normalize(train_images, axis=1)

# %%
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
#Picking 10% for testing and remaining for training
from sklearn.model_selection import train_test_split
X1, X_test, y1, y_test = train_test_split(train_images, train_masks_input, test_size = 0.10, shuffle=True, random_state = 42)

# %%
#Further split training data to a smaller subset for quick training
X_train, X_do_not_use, y_train, y_do_not_use = train_test_split(X1, y1, test_size = 0.5, shuffle=True, random_state = 42)

# %%
print("Class values in the dataset are ... ", np.unique(y_train))
# Out:
# Class values in the dataset are ...  [0 1 2 3 4 5]

# %%
#Optional
#Convert classes 0,1,2,3 to categories
from keras.utils.np_utils import to_categorical

n_classes=6

train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))

test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# %%
#Get U-Net from unet_model notebook
# %run unet_model.ipynb

# %%
def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

# %%
model = get_model()

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#NOTE: Instead of crossentropy, can use vocal loss for imbalanced data problem

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 16  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 6)  102         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,940,902
# Trainable params: 1,940,902
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, 
                    y_train_cat, 
                    #batch_size = 8,
                    #batch_size = 16,
                    batch_size = 32,
                    epochs=50, 
                    verbose=1,
                    validation_data=(X_test, y_test_cat) 
                   )
# Out:
# Epoch 1/50
# 14/14 [==============================] - 108s 6s/step - loss: 1.8441 - accuracy: 0.2218 - val_loss: 1.7525 - val_accuracy: 0.2889
# Epoch 2/50
# 14/14 [==============================] - 76s 6s/step - loss: 1.7125 - accuracy: 0.2659 - val_loss: 1.6422 - val_accuracy: 0.2884
# Epoch 3/50
# 14/14 [==============================] - 72s 5s/step - loss: 1.5689 - accuracy: 0.2819 - val_loss: 1.4795 - val_accuracy: 0.2745
# Epoch 4/50
# 14/14 [==============================] - 73s 5s/step - loss: 1.4789 - accuracy: 0.3057 - val_loss: 1.4158 - val_accuracy: 0.4195
# Epoch 5/50
# 14/14 [==============================] - 71s 5s/step - loss: 1.4307 - accuracy: 0.3751 - val_loss: 1.3499 - val_accuracy: 0.4631
# Epoch 6/50
# 14/14 [==============================] - 72s 5s/step - loss: 1.3883 - accuracy: 0.4180 - val_loss: 1.2841 - val_accuracy: 0.4778
# Epoch 7/50
# 14/14 [==============================] - 71s 5s/step - loss: 1.3043 - accuracy: 0.4478 - val_loss: 1.2176 - val_accuracy: 0.5593
# Epoch 8/50
# 14/14 [==============================] - 70s 5s/step - loss: 1.1984 - accuracy: 0.5886 - val_loss: 1.0976 - val_accuracy: 0.6509
# Epoch 9/50
# 14/14 [==============================] - 71s 5s/step - loss: 1.0245 - accuracy: 0.6770 - val_loss: 1.0101 - val_accuracy: 0.7025
# Epoch 10/50
# 14/14 [==============================] - 69s 5s/step - loss: 0.9208 - accuracy: 0.7126 - val_loss: 0.9308 - val_accuracy: 0.6995
# Epoch 11/50
# 14/14 [==============================] - 71s 5s/step - loss: 0.8827 - accuracy: 0.7183 - val_loss: 0.9272 - val_accuracy: 0.7108
# Epoch 12/50
# 14/14 [==============================] - 70s 5s/step - loss: 0.8657 - accuracy: 0.7252 - val_loss: 0.9018 - val_accuracy: 0.7203
# Epoch 13/50
# 14/14 [==============================] - 70s 5s/step - loss: 0.8395 - accuracy: 0.7288 - val_loss: 0.8642 - val_accuracy: 0.7252
# Epoch 14/50
# 14/14 [==============================] - 72s 5s/step - loss: 0.8139 - accuracy: 0.7377 - val_loss: 0.8624 - val_accuracy: 0.7257
# Epoch 15/50
# 14/14 [==============================] - 68s 5s/step - loss: 0.8016 - accuracy: 0.7407 - val_loss: 0.8909 - val_accuracy: 0.7229
# Epoch 16/50
# 14/14 [==============================] - 67s 5s/step - loss: 0.7962 - accuracy: 0.7425 - val_loss: 0.9667 - val_accuracy: 0.7148
# Epoch 17/50
# 14/14 [==============================] - 54s 4s/step - loss: 0.7951 - accuracy: 0.7424 - val_loss: 0.8171 - val_accuracy: 0.7387
# Epoch 18/50
# 14/14 [==============================] - 53s 4s/step - loss: 0.7758 - accuracy: 0.7457 - val_loss: 0.8236 - val_accuracy: 0.7382
# Epoch 19/50
# 14/14 [==============================] - 53s 4s/step - loss: 0.7590 - accuracy: 0.7497 - val_loss: 0.8131 - val_accuracy: 0.7424
# Epoch 20/50
# 14/14 [==============================] - 53s 4s/step - loss: 0.7500 - accuracy: 0.7521 - val_loss: 0.8108 - val_accuracy: 0.7445
# Epoch 21/50
# 14/14 [==============================] - 54s 4s/step - loss: 0.7563 - accuracy: 0.7527 - val_loss: 0.8462 - val_accuracy: 0.7312
# Epoch 22/50
# 14/14 [==============================] - 55s 4s/step - loss: 0.7488 - accuracy: 0.7545 - val_loss: 0.8056 - val_accuracy: 0.7453
# Epoch 23/50
# 14/14 [==============================] - 54s 4s/step - loss: 0.7468 - accuracy: 0.7531 - val_loss: 0.8225 - val_accuracy: 0.7398
# Epoch 24/50
# 14/14 [==============================] - 54s 4s/step - loss: 0.7338 - accuracy: 0.7584 - val_loss: 0.8440 - val_accuracy: 0.7424
# Epoch 25/50
# 14/14 [==============================] - 52s 4s/step - loss: 0.7323 - accuracy: 0.7574 - val_loss: 0.7847 - val_accuracy: 0.7443
# Epoch 26/50
# 14/14 [==============================] - 41s 3s/step - loss: 0.7185 - accuracy: 0.7615 - val_loss: 0.8078 - val_accuracy: 0.7438
# Epoch 27/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.7293 - accuracy: 0.7595 - val_loss: 0.8063 - val_accuracy: 0.7483
# Epoch 28/50
# 14/14 [==============================] - 38s 3s/step - loss: 0.7261 - accuracy: 0.7608 - val_loss: 0.8115 - val_accuracy: 0.7488
# Epoch 29/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.7077 - accuracy: 0.7665 - val_loss: 0.8166 - val_accuracy: 0.7466
# Epoch 30/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.6993 - accuracy: 0.7680 - val_loss: 0.8440 - val_accuracy: 0.7470
# Epoch 31/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6845 - accuracy: 0.7742 - val_loss: 0.8010 - val_accuracy: 0.7528
# Epoch 32/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.6691 - accuracy: 0.7791 - val_loss: 0.8296 - val_accuracy: 0.7522
# Epoch 33/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.6704 - accuracy: 0.7775 - val_loss: 0.7850 - val_accuracy: 0.7555
# Epoch 34/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6595 - accuracy: 0.7836 - val_loss: 0.7908 - val_accuracy: 0.7590
# Epoch 35/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6429 - accuracy: 0.7901 - val_loss: 0.7867 - val_accuracy: 0.7634
# Epoch 36/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6433 - accuracy: 0.7894 - val_loss: 0.7801 - val_accuracy: 0.7592
# Epoch 37/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6443 - accuracy: 0.7906 - val_loss: 0.7668 - val_accuracy: 0.7574
# Epoch 38/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.6435 - accuracy: 0.7894 - val_loss: 0.7864 - val_accuracy: 0.7635
# Epoch 39/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.6217 - accuracy: 0.7994 - val_loss: 0.7619 - val_accuracy: 0.7693
# Epoch 40/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6199 - accuracy: 0.8012 - val_loss: 0.7798 - val_accuracy: 0.7619
# Epoch 41/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6367 - accuracy: 0.7940 - val_loss: 0.7929 - val_accuracy: 0.7622
# Epoch 42/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.6181 - accuracy: 0.8021 - val_loss: 0.7596 - val_accuracy: 0.7656
# Epoch 43/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5886 - accuracy: 0.8118 - val_loss: 0.7749 - val_accuracy: 0.7635
# Epoch 44/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5895 - accuracy: 0.8127 - val_loss: 0.7564 - val_accuracy: 0.7670
# Epoch 45/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5644 - accuracy: 0.8212 - val_loss: 0.7914 - val_accuracy: 0.7643
# Epoch 46/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5481 - accuracy: 0.8257 - val_loss: 0.7978 - val_accuracy: 0.7701
# Epoch 47/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5389 - accuracy: 0.8298 - val_loss: 0.7656 - val_accuracy: 0.7726
# Epoch 48/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5246 - accuracy: 0.8346 - val_loss: 0.8051 - val_accuracy: 0.7725
# Epoch 49/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.5355 - accuracy: 0.8295 - val_loss: 0.7503 - val_accuracy: 0.7769
# Epoch 50/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.5341 - accuracy: 0.8297 - val_loss: 0.7430 - val_accuracy: 0.7832

# %%
model.save('unet_50_32_saroadscenesdata_f5.hdf5')

# %%
#Evaluate the model
#_, acc = model.evaluate(X_test, y_test_cat)
#print("Accuracy is = ", (acc * 100.0), "%")

# %% [markdown]
# # Batch 8 - plots

# %%
#Fold-1
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-2
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-3
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-4
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-5
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Batch 16 - plots

# %%
#Fold-1
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-2
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-3
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-4
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-5
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Batch 32 - plots

# %%
#Fold-1
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-2
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-3
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-4
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Fold-5
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

#BATCH 8
model = load_model('unet_50_saroadscenesdata_f1.hdf5', compile=False)
#model = load_model('unet_50_saroadscenesdata_f2.hdf5', compile=False)
#model = load_model('unet_50_saroadscenesdata_f3.hdf5', compile=False)
#model = load_model('unet_50_saroadscenesdata_f4.hdf5', compile=False)
#model = load_model('unet_50_saroadscenesdata_f5.hdf5', compile=False)
#BATCH 16
#model = load_model('unet_50_16_saroadscenesdata_f1.hdf5', compile=False)
#model = load_model('unet_50_16_saroadscenesdata_f2.hdf5', compile=False)
#model = load_model('unet_50_16_saroadscenesdata_f3.hdf5', compile=False)
#model = load_model('unet_50_16_saroadscenesdata_f4.hdf5', compile=False)
#model = load_model('unet_50_16_saroadscenesdata_f5.hdf5', compile=False)
#BATCH 32
#model = load_model('unet_50_32_saroadscenesdata_f1.hdf5', compile=False)
#model = load_model('unet_50_32_saroadscenesdata_f2.hdf5', compile=False)
#model = load_model('unet_50_32_saroadscenesdata_f3.hdf5', compile=False)
#model = load_model('unet_50_32_saroadscenesdata_f4.hdf5', compile=False)
#model = load_model('unet_50_32_saroadscenesdata_f5.hdf5', compile=False)

# %% [markdown]
# # Calculating results

# %%
#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)

# %%
from keras.metrics import MeanIoU
n_classes = 6
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test[:,:,:,0], y_pred_argmax)
# Out:
# <tf.Variable 'UnreadVariable' shape=(6, 6) dtype=float32, numpy=
# array([[3.50618e+05, 1.21070e+04, 1.72400e+03, 0.00000e+00, 6.25910e+04,
#         3.85300e+04],
#        [5.15380e+04, 3.57230e+04, 5.70000e+01, 0.00000e+00, 5.94900e+03,
#         1.90870e+04],
#        [1.89600e+04, 6.87000e+02, 1.42490e+04, 0.00000e+00, 9.73300e+03,
#         5.28300e+03],
#        [9.93500e+03, 6.29000e+02, 1.59000e+02, 0.00000e+00, 2.81300e+03,
#         5.23200e+03],
#        [4.51560e+04, 1.40300e+03, 1.41500e+03, 0.00000e+00, 3.64308e+05,
#         1.67030e+04],
#        [2.58880e+04, 7.03400e+03, 1.57000e+02, 0.00000e+00, 5.36500e+03,
#         4.92599e+05]], dtype=float32)>

# %%
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.43546915

# %%
#To calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[0,4] + values[0,5] + values[1,0] + values[2,0] + values[3,0] + values[4,0] + values[5,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[1,4] + values[1,5] + values[0,1] + values[2,1] + values[3,1] + values[4,1] + values[5,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[2,4] + values[2,5] + values[0,2] + values[1,2] + values[3,2] + values[4,2] + values[5,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[3,4] + values[3,5] + values[0,3] + values[1,3] + values[2,3] + values[4,3] + values[5,3])
class5_IoU = values[4,4]/(values[4,4] + values[4,0] + values[4,1] + values[4,2] + values[4,3] + values[4,5] + values[0,4] + values[1,4] + values[2,4] + values[3,4] + values[5,4])
class6_IoU = values[5,5]/(values[5,5] + values[5,0] + values[5,1] + values[5,2] + values[5,3] + values[5,4] + values[0,5] + values[1,5] + values[2,5] + values[3,5] + values[4,5])
# Out:
# [[3.50618e+05 1.21070e+04 1.72400e+03 0.00000e+00 6.25910e+04 3.85300e+04]
#  [5.15380e+04 3.57230e+04 5.70000e+01 0.00000e+00 5.94900e+03 1.90870e+04]
#  [1.89600e+04 6.87000e+02 1.42490e+04 0.00000e+00 9.73300e+03 5.28300e+03]
#  [9.93500e+03 6.29000e+02 1.59000e+02 0.00000e+00 2.81300e+03 5.23200e+03]
#  [4.51560e+04 1.40300e+03 1.41500e+03 0.00000e+00 3.64308e+05 1.67030e+04]
#  [2.58880e+04 7.03400e+03 1.57000e+02 0.00000e+00 5.36500e+03 4.92599e+05]]

# %%
print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)
print("IoU for class5 is: ", class5_IoU)
print("IoU for class6 is: ", class6_IoU)
# Out:
# IoU for class1 is:  0.5682193
# IoU for class2 is:  0.26616448
# IoU for class3 is:  0.271803
# IoU for class4 is:  0.0
# IoU for class5 is:  0.7067958
# IoU for class6 is:  0.7998321

# %%
plt.imshow(train_images[0, :,:,0], cmap='gray')

# %%
plt.imshow(train_masks[0], cmap='gray')

# %% [markdown]
# # Batch 8 - test

# %%
#Fold-1
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-2
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-3
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-4
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-5
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %% [markdown]
# # Batch 16 - test

# %%
#Fold-1
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-2
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-3
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-4
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-5
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %% [markdown]
# # Batch 32 - test

# %%
#Fold-1
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-2
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-3
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-4
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# %%
#Fold-5
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img_norm, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='jet')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='jet')
plt.show()
